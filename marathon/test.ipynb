# %%
import pandas as pd

# %%
test = pd.read_csv("./data/SampleSubmission.csv")
test
# Out:
#                             customerid  Good_Bad_flag
# 0     8a28afc7474813a40147639ec637156b              1
# 1     8a3735d5518aba7301518ac34413010d              1
# 2     8a76e7d443e6e97c0143ed099d102b1d              1
# 3     8a818823525dceef01525deda2480384              1
# 4     8a818926522ea5ef01523aff15c37482              1
# ...                                ...            ...
# 1445  8a858fff5a36fe68015a3744f0021e89              1
# 1446  8aaae7a74400b28201441c8b62514150              1
# 1447  8aab10f748cf78ff0148d11fac1447a6              1
# 1448  8aab160f499477da014999ba2f0f578b              1
# 1449  8addcb0645aff34b0145b25fe1616ee0              1
#
# [1450 rows x 2 columns]

# %%
izy = pd.read_csv("./testdata.csv")
izy
# Out:
#                             customerid  loannumber  loanamount  totaldue  \
# 0     8a28afc7474813a40147639ec637156b          11       25000   27500.0
# 1     8a3735d5518aba7301518ac34413010d           7       20000   24500.0
# 2     8a76e7d443e6e97c0143ed099d102b1d           6       20000   24500.0
# 3     8a818823525dceef01525deda2480384          10       40000   48000.0
# 4     8a818926522ea5ef01523aff15c37482           3       20000   24500.0
# ...                                ...         ...         ...       ...
# 1445  8a858fff5a36fe68015a3744f0021e89           6       20000   24500.0
# 1446  8aaae7a74400b28201441c8b62514150           4       10000   13000.0
# 1447  8aab10f748cf78ff0148d11fac1447a6           2       10000   13000.0
# 1448  8aab160f499477da014999ba2f0f578b           4       20000   23000.0
# 1449  8addcb0645aff34b0145b25fe1616ee0           5       20000   24500.0
#
#       termdays        age  loan_interest  loan_received  amount_received  \
# ...

# %%
r = pd.read_csv("./submission.csv")
list(r["bad_good_flag"]).count(1)
# Out:
# 1366

# %%
list(r["bad_good_flag"]).count(0)
# Out:
# 84
