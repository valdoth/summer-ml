# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 


from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,f1_score,precision_score,recall_score

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ### 1.demographics

# %%
train_demographics = pd.read_csv("./data/testdemographics.csv")
train_demographics
# Out:
#                             customerid                   birthdate  \
# 0     8a858f305c8dd672015c93b1db645db4  1976-08-28 00:00:00.000000
# 1     8a858f085a477386015a47fb049e49ca  1978-06-23 00:00:00.000000
# 2     8a858e6f5cd5e874015cd6f5634c39ad  1984-04-04 00:00:00.000000
# 3     8a858e9d5bfd7037015bfdab79f61305  1983-05-28 00:00:00.000000
# 4     8a858fde56eb02280156eb6dafc128ac  1982-03-29 00:00:00.000000
# ...                                ...                         ...
# 1482  8a858fc25bafabdc015bb47fda0323e5  1976-04-13 00:00:00.000000
# 1483  8a858e245c214660015c3397e4db389a  1990-10-24 00:00:00.000000
# 1484  8a858e8b5bc9e7e6015bcd7374077f0c  1988-06-12 00:00:00.000000
# 1485  8a858f2e5c699f3a015c77aa22ed7f23  1974-03-23 00:00:00.000000
# 1486  8a858fde580afd48015818eda53830c8  1987-02-16 00:00:00.000000
#
#      bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 0              Savings       5.296628      7.593965     Heritage Bank
# 1              Savings       3.294513      6.596602               UBA
# 2              Savings       8.501912      7.729364        First Bank
# 3              Savings       3.318904      6.681595               UBA
# 4              Savings       6.354624      4.949031        First Bank
# ...                ...            ...           ...               ...
# 1482           Savings       3.481190      6.442728           GT Bank
# 1483           Savings       4.738209      8.179723           GT Bank
# 1484           Savings       3.424825      6.455802        First Bank
# 1485           Savings       3.318851      7.113212              FCMB
# 1486           Savings       3.372462      6.563372      Stanbic IBTC
#
#      bank_branch_clients employment_status_clients level_of_education_clients
# 0                    NaN                 Permanent                        NaN
# 1                    NaN                 Permanent                        NaN
# 2                    NaN                 Permanent                        NaN
# 3                    NaN                 Permanent                        NaN
# 4                    NaN             Self-Employed                        NaN
# ...                  ...                       ...                        ...
# 1482                 NaN                 Permanent                        NaN
# 1483                 NaN                 Permanent                        NaN
# 1484                 NaN                 Permanent                        NaN
# 1485                 NaN                 Permanent                        NaN
# 1486                 NaN                 Permanent                   Graduate
#
# [1487 rows x 9 columns]

# %%
train_demographics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1487 entries, 0 to 1486
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customerid                  1487 non-null   object
#  1   birthdate                   1487 non-null   object
#  2   bank_account_type           1487 non-null   object
#  3   longitude_gps               1487 non-null   float64
#  4   latitude_gps                1487 non-null   float64
#  5   bank_name_clients           1487 non-null   object
#  6   bank_branch_clients         14 non-null     object
#  7   employment_status_clients   1270 non-null   object
#  8   level_of_education_clients  210 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 104.7+ KB

# %% [markdown]
# ### 2.trainperf

# %%
train_perf = pd.read_csv("./data/testperf.csv")
train_perf
# Out:
#                             customerid  systemloanid  loannumber approveddate  \
# 0     8a858899538ddb8e015390510b321f08     301998974           4      40:48.0
# 1     8a858959537a097401537a4e316e25f7     301963615          10      43:40.0
# 2     8a8589c253ace09b0153af6ba58f1f31     301982236           6      15:11.0
# 3     8a858e095aae82b7015aae86ca1e030b     301971730           8      00:54.0
# 4     8a858e225a28c713015a30db5c48383d     301959177           4      04:33.0
# ...                                ...           ...         ...          ...
# 1445  8a858fb45bb59c21015bb88a191f58f2     301991141           3      47:02.0
# 1446  8a858fcb5b00cc54015b0253ced26a5f     301963018           3      00:45.0
# 1447  8a858fde56eb02280156f59b976d46c0     301994653           9      09:40.0
# 1448  8a858e10570f2d65015717fcfec44996     301961483          14      47:54.0
# 1449  8a858f605b911d60015b91b99d55400d     301973097           6      12:09.0
#
#      creationdate  loanamount  totaldue  termdays  \
# 0         39:35.0       10000   12250.0        30
# 1         42:34.0       40000   44000.0        30
# 2         15:04.0       20000   24500.0        30
# 3         00:49.0       30000   34500.0        30
# 4         04:27.0       20000   24500.0        30
# ...           ...         ...       ...       ...
# 1445      46:53.0       10000   11500.0        15
# 1446      04:05.0       10000   13000.0        30
# 1447      09:33.0       40000   48000.0        60
# 1448      46:49.0       60000   68100.0        90
# 1449      12:03.0       20000   22250.0        15
#
#                             referredby
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 1445                               NaN
# 1446                               NaN
# 1447                               NaN
# 1448                               NaN
# 1449  8a858ff259d1429e0159d2d0194c4b8e
#
# [1450 rows x 9 columns]

# %%
train_perf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   customerid    1450 non-null   object
#  1   systemloanid  1450 non-null   int64
#  2   loannumber    1450 non-null   int64
#  3   approveddate  1450 non-null   object
#  4   creationdate  1450 non-null   object
#  5   loanamount    1450 non-null   int64
#  6   totaldue      1450 non-null   float64
#  7   termdays      1450 non-null   int64
#  8   referredby    184 non-null    object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 102.1+ KB

# %% [markdown]
# ### 3.trainprevloans

# %%
train_prevloans = pd.read_csv("./data/testprevloans.csv")
train_prevloans
# Out:
#                             customerid  systemloanid  loannumber  \
# 0     8a858899538ddb8e015390510b321f08     301621635           3
# 1     8a858959537a097401537a4e316e25f7     301810201           5
# 2     8a858959537a097401537a4e316e25f7     301831255           6
# 3     8a8589c253ace09b0153af6ba58f1f31     301627292           3
# 4     8a8589c253ace09b0153af6ba58f1f31     301621095           2
# ...                                ...           ...         ...
# 5902  8a858f085b494826015b54a0b2a1093b     301861709           1
# 5903  8a858f565b683b56015b7391c2617960     301869817           1
# 5904  8a858fab5b9105dc015b975e594e394a     301952446           1
# 5905  8a858fcf5b39c3ba015b39c7691603e1     301887884           2
# 5906  8a858e165cf9d8e3015cfffb0c61459f     301959483           1
#
#                     approveddate                creationdate  loanamount  \
# 0     2016-05-17 10:37:00.000000  2016-05-17 09:36:55.000000     10000.0
# 1     2017-02-04 21:28:59.000000  2017-02-04 20:28:52.000000     30000.0
# 2     2017-03-04 10:28:22.000000  2017-03-04 09:28:16.000000     30000.0
# 3     2016-06-02 14:27:14.000000  2016-06-02 13:27:08.000000     10000.0
# 4     2016-05-16 09:13:12.000000  2016-05-16 08:13:04.000000     10000.0
# ...                          ...                         ...         ...
# 5902  2017-04-09 23:04:32.000000  2017-04-09 22:04:10.000000     10000.0
# 5903  2017-04-15 23:33:17.000000  2017-04-15 22:33:05.000000     10000.0
# 5904  2017-06-26 15:46:28.000000  2017-06-26 14:45:20.000000     10000.0
# 5905  2017-05-03 06:56:10.000000  2017-05-03 05:56:04.000000     10000.0
# 5906  2017-07-01 22:23:15.000000  2017-07-01 21:22:08.000000     10000.0
#
#       totaldue  termdays                  closeddate  \
# 0      13000.0        30  2016-06-17 00:04:15.000000
# 1      36800.0        60  2017-03-02 16:22:58.000000
# 2      34400.0        30  2017-04-02 00:44:24.000000
# 3      13000.0        30  2016-07-04 11:34:04.000000
# 4      11500.0        15  2016-06-02 00:02:58.000000
# ...        ...       ...                         ...
# 5902   13000.0        30  2017-05-02 22:27:03.000000
# 5903   11500.0        15  2017-04-25 19:32:42.000000
# 5904   13000.0        30  2017-07-13 13:12:43.000000
# 5905   13000.0        30  2017-06-01 22:00:17.000000
# 5906   13000.0        30  2017-07-29 14:25:20.000000
#
#                             referredby                firstduedate  \
# 0                                  NaN  2016-06-16 00:00:00.000000
# 1                                  NaN  2017-03-06 00:00:00.000000
# 2                                  NaN  2017-04-03 00:00:00.000000
# 3                                  NaN  2016-07-04 00:00:00.000000
# 4                                  NaN  2016-05-31 00:00:00.000000
# ...                                ...                         ...
# 5902  8a858e4f5929c3df0159420645f46f55  2017-05-09 00:00:00.000000
# 5903                               NaN  2017-05-02 00:00:00.000000
# 5904                               NaN  2017-07-26 00:00:00.000000
# 5905                               NaN  2017-06-02 00:00:00.000000
# 5906                               NaN  2017-07-31 00:00:00.000000
#
#                  firstrepaiddate
# 0     2016-06-16 15:44:08.000000
# 1     2017-03-02 16:07:47.000000
# 2     2017-04-01 21:29:46.000000
# 3     2016-07-04 11:19:01.000000
# 4     2016-06-01 15:22:34.000000
# ...                          ...
# 5902  2017-05-02 22:11:54.000000
# 5903  2017-04-25 19:17:33.000000
# 5904  2017-07-13 13:02:34.000000
# 5905  2017-06-01 21:50:07.000000
# 5906  2017-07-29 14:15:11.000000
#
# [5907 rows x 12 columns]

# %%
train_prevloans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5907 entries, 0 to 5906
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customerid       5907 non-null   object
#  1   systemloanid     5907 non-null   int64
#  2   loannumber       5907 non-null   int64
#  3   approveddate     5907 non-null   object
#  4   creationdate     5907 non-null   object
#  5   loanamount       5907 non-null   float64
#  6   totaldue         5907 non-null   float64
#  7   termdays         5907 non-null   int64
#  8   closeddate       5907 non-null   object
#  9   referredby       325 non-null    object
#  10  firstduedate     5907 non-null   object
#  11  firstrepaiddate  5907 non-null   object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 553.9+ KB

# %% [markdown]
# ### merge train_demographics in train_perf data

# %%
train_data = pd.merge(train_perf, train_demographics, on="customerid", how="left")
train_data
# Out:
#                             customerid  systemloanid  loannumber approveddate  \
# 0     8a858899538ddb8e015390510b321f08     301998974           4      40:48.0
# 1     8a858959537a097401537a4e316e25f7     301963615          10      43:40.0
# 2     8a8589c253ace09b0153af6ba58f1f31     301982236           6      15:11.0
# 3     8a858e095aae82b7015aae86ca1e030b     301971730           8      00:54.0
# 4     8a858e225a28c713015a30db5c48383d     301959177           4      04:33.0
# ...                                ...           ...         ...          ...
# 1445  8a858fb45bb59c21015bb88a191f58f2     301991141           3      47:02.0
# 1446  8a858fcb5b00cc54015b0253ced26a5f     301963018           3      00:45.0
# 1447  8a858fde56eb02280156f59b976d46c0     301994653           9      09:40.0
# 1448  8a858e10570f2d65015717fcfec44996     301961483          14      47:54.0
# 1449  8a858f605b911d60015b91b99d55400d     301973097           6      12:09.0
#
#      creationdate  loanamount  totaldue  termdays  \
# 0         39:35.0       10000   12250.0        30
# 1         42:34.0       40000   44000.0        30
# 2         15:04.0       20000   24500.0        30
# 3         00:49.0       30000   34500.0        30
# 4         04:27.0       20000   24500.0        30
# ...           ...         ...       ...       ...
# 1445      46:53.0       10000   11500.0        15
# 1446      04:05.0       10000   13000.0        30
# 1447      09:33.0       40000   48000.0        60
# 1448      46:49.0       60000   68100.0        90
# 1449      12:03.0       20000   22250.0        15
#
#                             referredby                   birthdate  \
# 0                                  NaN                         NaN
# 1                                  NaN                         NaN
# 2                                  NaN  1981-09-05 00:00:00.000000
# 3                                  NaN                         NaN
# 4                                  NaN  1975-08-25 00:00:00.000000
# ...                                ...                         ...
# 1445                               NaN                         NaN
# 1446                               NaN                         NaN
# 1447                               NaN                         NaN
# 1448                               NaN                         NaN
# 1449  8a858ff259d1429e0159d2d0194c4b8e                         NaN
#
#      bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 0                  NaN            NaN           NaN               NaN
# 1                  NaN            NaN           NaN               NaN
# 2              Savings       3.227945      6.586668               UBA
# 3                  NaN            NaN           NaN               NaN
# 4              Savings       5.248368     13.059864               UBA
# ...                ...            ...           ...               ...
# 1445               NaN            NaN           NaN               NaN
# 1446               NaN            NaN           NaN               NaN
# 1447               NaN            NaN           NaN               NaN
# 1448               NaN            NaN           NaN               NaN
# 1449               NaN            NaN           NaN               NaN
#
#      bank_branch_clients employment_status_clients level_of_education_clients
# 0                    NaN                       NaN                        NaN
# 1                    NaN                       NaN                        NaN
# 2                    NaN                 Permanent                        NaN
# 3                    NaN                       NaN                        NaN
# 4                    NaN                 Permanent                        NaN
# ...                  ...                       ...                        ...
# 1445                 NaN                       NaN                        NaN
# 1446                 NaN                       NaN                        NaN
# 1447                 NaN                       NaN                        NaN
# 1448                 NaN                       NaN                        NaN
# 1449                 NaN                       NaN                        NaN
#
# [1450 rows x 17 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1450 entries, 0 to 1449
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customerid                  1450 non-null   object
#  1   systemloanid                1450 non-null   int64
#  2   loannumber                  1450 non-null   int64
#  3   approveddate                1450 non-null   object
#  4   creationdate                1450 non-null   object
#  5   loanamount                  1450 non-null   int64
#  6   totaldue                    1450 non-null   float64
#  7   termdays                    1450 non-null   int64
#  8   referredby                  184 non-null    object
#  9   birthdate                   385 non-null    object
#  10  bank_account_type           385 non-null    object
#  11  longitude_gps               385 non-null    float64
#  12  latitude_gps                385 non-null    float64
#  13  bank_name_clients           385 non-null    object
#  14  bank_branch_clients         4 non-null      object
#  15  employment_status_clients   332 non-null    object
#  16  level_of_education_clients  47 non-null     object
# dtypes: float64(3), int64(4), object(10)
# memory usage: 203.9+ KB

# %% [markdown]
# ### A stastistical summary of the numerical attributes

# %%
train_data.describe()
# Out:
#        systemloanid   loannumber    loanamount      totaldue     termdays  \
# count  1.450000e+03  1450.000000   1450.000000   1450.000000  1450.000000
# mean   3.019807e+08     5.088966  17482.758621  20874.664069    28.810345
# std    1.339572e+04     3.665210  10585.420034  11726.584630    11.074839
# min    3.019585e+08     2.000000  10000.000000  10500.000000    15.000000
# 25%    3.019687e+08     2.000000  10000.000000  13000.000000    30.000000
# 50%    3.019799e+08     4.000000  10000.000000  13000.000000    30.000000
# 75%    3.019929e+08     7.000000  20000.000000  24500.000000    30.000000
# max    3.020040e+08    34.000000  60000.000000  68100.000000    90.000000
#
#        longitude_gps  latitude_gps
# count     385.000000    385.000000
# mean        4.062788      7.112367
# std         7.905697      4.967113
# min       -97.883895    -74.005974
# 25%         3.355934      6.482848
# 50%         3.617318      6.640428
# 75%         5.985538      7.441765
# max        11.325827     40.665105

# %% [markdown]
# ### valeurs manquantes

# %%
def missing_value_rate(data):
    return 100 * data.isna().sum() / data.shape[0]

# %%
missing_value_rate(train_data)
# Out:
# customerid                     0.000000
# systemloanid                   0.000000
# loannumber                     0.000000
# approveddate                   0.000000
# creationdate                   0.000000
# loanamount                     0.000000
# totaldue                       0.000000
# termdays                       0.000000
# referredby                    87.310345
# birthdate                     73.448276
# bank_account_type             73.448276
# longitude_gps                 73.448276
# latitude_gps                  73.448276
# bank_name_clients             73.448276
# bank_branch_clients           99.724138
# employment_status_clients     77.103448
# level_of_education_clients    96.758621
# dtype: float64

# %%
train_data.isnull().sum()
# Out:
# customerid                       0
# systemloanid                     0
# loannumber                       0
# approveddate                     0
# creationdate                     0
# loanamount                       0
# totaldue                         0
# termdays                         0
# referredby                    1266
# birthdate                     1065
# bank_account_type             1065
# longitude_gps                 1065
# latitude_gps                  1065
# bank_name_clients             1065
# bank_branch_clients           1446
# employment_status_clients     1118
# level_of_education_clients    1403
# dtype: int64

# %% [markdown]
# ##### remplacer les dates en datetime

# %%
#train_data['approveddate'] = pd.to_datetime(train_data['approveddate'])
#train_data['creationdate'] = pd.to_datetime(train_data['creationdate'])
train_data['birthdate'] = pd.to_datetime(train_data['birthdate'])

# %% [markdown]
# ##### recupérer l'age de chaque client

# %%
approved_year = 2017
train_data["birthdate"] = approved_year - train_data["birthdate"].dt.year

# %% [markdown]
# ###### rénomer la colonne birthdate to age

# %%
train_data.rename(columns = {'birthdate' : 'age'}, inplace=True)

# %%
train_data
# Out:
#                             customerid  systemloanid  loannumber approveddate  \
# 0     8a858899538ddb8e015390510b321f08     301998974           4      40:48.0
# 1     8a858959537a097401537a4e316e25f7     301963615          10      43:40.0
# 2     8a8589c253ace09b0153af6ba58f1f31     301982236           6      15:11.0
# 3     8a858e095aae82b7015aae86ca1e030b     301971730           8      00:54.0
# 4     8a858e225a28c713015a30db5c48383d     301959177           4      04:33.0
# ...                                ...           ...         ...          ...
# 1445  8a858fb45bb59c21015bb88a191f58f2     301991141           3      47:02.0
# 1446  8a858fcb5b00cc54015b0253ced26a5f     301963018           3      00:45.0
# 1447  8a858fde56eb02280156f59b976d46c0     301994653           9      09:40.0
# 1448  8a858e10570f2d65015717fcfec44996     301961483          14      47:54.0
# 1449  8a858f605b911d60015b91b99d55400d     301973097           6      12:09.0
#
#      creationdate  loanamount  totaldue  termdays  \
# 0         39:35.0       10000   12250.0        30
# 1         42:34.0       40000   44000.0        30
# 2         15:04.0       20000   24500.0        30
# 3         00:49.0       30000   34500.0        30
# 4         04:27.0       20000   24500.0        30
# ...           ...         ...       ...       ...
# 1445      46:53.0       10000   11500.0        15
# 1446      04:05.0       10000   13000.0        30
# 1447      09:33.0       40000   48000.0        60
# 1448      46:49.0       60000   68100.0        90
# 1449      12:03.0       20000   22250.0        15
#
#                             referredby   age bank_account_type  longitude_gps  \
# 0                                  NaN   NaN               NaN            NaN
# 1                                  NaN   NaN               NaN            NaN
# 2                                  NaN  36.0           Savings       3.227945
# 3                                  NaN   NaN               NaN            NaN
# 4                                  NaN  42.0           Savings       5.248368
# ...                                ...   ...               ...            ...
# 1445                               NaN   NaN               NaN            NaN
# 1446                               NaN   NaN               NaN            NaN
# 1447                               NaN   NaN               NaN            NaN
# 1448                               NaN   NaN               NaN            NaN
# 1449  8a858ff259d1429e0159d2d0194c4b8e   NaN               NaN            NaN
#
#       latitude_gps bank_name_clients bank_branch_clients  \
# 0              NaN               NaN                 NaN
# 1              NaN               NaN                 NaN
# 2         6.586668               UBA                 NaN
# 3              NaN               NaN                 NaN
# 4        13.059864               UBA                 NaN
# ...            ...               ...                 ...
# 1445           NaN               NaN                 NaN
# 1446           NaN               NaN                 NaN
# 1447           NaN               NaN                 NaN
# 1448           NaN               NaN                 NaN
# 1449           NaN               NaN                 NaN
#
#      employment_status_clients level_of_education_clients
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                    Permanent                        NaN
# 3                          NaN                        NaN
# 4                    Permanent                        NaN
# ...                        ...                        ...
# 1445                       NaN                        NaN
# 1446                       NaN                        NaN
# 1447                       NaN                        NaN
# 1448                       NaN                        NaN
# 1449                       NaN                        NaN
#
# [1450 rows x 17 columns]

# %% [markdown]
# ##### remplacer les valeurs age manquante par la moyenne d'age des clients

# %%
train_data['age'].fillna(train_data['age'].mean(), inplace=True)

# %%
train_data
# Out:
#                             customerid  systemloanid  loannumber approveddate  \
# 0     8a858899538ddb8e015390510b321f08     301998974           4      40:48.0
# 1     8a858959537a097401537a4e316e25f7     301963615          10      43:40.0
# 2     8a8589c253ace09b0153af6ba58f1f31     301982236           6      15:11.0
# 3     8a858e095aae82b7015aae86ca1e030b     301971730           8      00:54.0
# 4     8a858e225a28c713015a30db5c48383d     301959177           4      04:33.0
# ...                                ...           ...         ...          ...
# 1445  8a858fb45bb59c21015bb88a191f58f2     301991141           3      47:02.0
# 1446  8a858fcb5b00cc54015b0253ced26a5f     301963018           3      00:45.0
# 1447  8a858fde56eb02280156f59b976d46c0     301994653           9      09:40.0
# 1448  8a858e10570f2d65015717fcfec44996     301961483          14      47:54.0
# 1449  8a858f605b911d60015b91b99d55400d     301973097           6      12:09.0
#
#      creationdate  loanamount  totaldue  termdays  \
# 0         39:35.0       10000   12250.0        30
# 1         42:34.0       40000   44000.0        30
# 2         15:04.0       20000   24500.0        30
# 3         00:49.0       30000   34500.0        30
# 4         04:27.0       20000   24500.0        30
# ...           ...         ...       ...       ...
# 1445      46:53.0       10000   11500.0        15
# 1446      04:05.0       10000   13000.0        30
# 1447      09:33.0       40000   48000.0        60
# 1448      46:49.0       60000   68100.0        90
# 1449      12:03.0       20000   22250.0        15
#
#                             referredby        age bank_account_type  \
# 0                                  NaN  32.618182               NaN
# 1                                  NaN  32.618182               NaN
# 2                                  NaN  36.000000           Savings
# 3                                  NaN  32.618182               NaN
# 4                                  NaN  42.000000           Savings
# ...                                ...        ...               ...
# 1445                               NaN  32.618182               NaN
# 1446                               NaN  32.618182               NaN
# 1447                               NaN  32.618182               NaN
# 1448                               NaN  32.618182               NaN
# 1449  8a858ff259d1429e0159d2d0194c4b8e  32.618182               NaN
#
#       longitude_gps  latitude_gps bank_name_clients bank_branch_clients  \
# 0               NaN           NaN               NaN                 NaN
# 1               NaN           NaN               NaN                 NaN
# 2          3.227945      6.586668               UBA                 NaN
# 3               NaN           NaN               NaN                 NaN
# 4          5.248368     13.059864               UBA                 NaN
# ...             ...           ...               ...                 ...
# 1445            NaN           NaN               NaN                 NaN
# 1446            NaN           NaN               NaN                 NaN
# 1447            NaN           NaN               NaN                 NaN
# 1448            NaN           NaN               NaN                 NaN
# 1449            NaN           NaN               NaN                 NaN
#
#      employment_status_clients level_of_education_clients
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                    Permanent                        NaN
# 3                          NaN                        NaN
# 4                    Permanent                        NaN
# ...                        ...                        ...
# 1445                       NaN                        NaN
# 1446                       NaN                        NaN
# 1447                       NaN                        NaN
# 1448                       NaN                        NaN
# 1449                       NaN                        NaN
#
# [1450 rows x 17 columns]

# %% [markdown]
# ##### voir les proportions de employment_status_clients

# %%
train_data['employment_status_clients'].value_counts()
# Out:
# Permanent        281
# Self-Employed     31
# Student           16
# Unemployed         3
# Retired            1
# Name: employment_status_clients, dtype: int64

# %% [markdown]
# ##### remplacer les valeurs de employment_status_clients par Unemployed

# %%
train_data["employment_status_clients"].fillna(value="Unemployed", inplace=True)

# %%
train_data
# Out:
#                             customerid  systemloanid  loannumber approveddate  \
# 0     8a858899538ddb8e015390510b321f08     301998974           4      40:48.0
# 1     8a858959537a097401537a4e316e25f7     301963615          10      43:40.0
# 2     8a8589c253ace09b0153af6ba58f1f31     301982236           6      15:11.0
# 3     8a858e095aae82b7015aae86ca1e030b     301971730           8      00:54.0
# 4     8a858e225a28c713015a30db5c48383d     301959177           4      04:33.0
# ...                                ...           ...         ...          ...
# 1445  8a858fb45bb59c21015bb88a191f58f2     301991141           3      47:02.0
# 1446  8a858fcb5b00cc54015b0253ced26a5f     301963018           3      00:45.0
# 1447  8a858fde56eb02280156f59b976d46c0     301994653           9      09:40.0
# 1448  8a858e10570f2d65015717fcfec44996     301961483          14      47:54.0
# 1449  8a858f605b911d60015b91b99d55400d     301973097           6      12:09.0
#
#      creationdate  loanamount  totaldue  termdays  \
# 0         39:35.0       10000   12250.0        30
# 1         42:34.0       40000   44000.0        30
# 2         15:04.0       20000   24500.0        30
# 3         00:49.0       30000   34500.0        30
# 4         04:27.0       20000   24500.0        30
# ...           ...         ...       ...       ...
# 1445      46:53.0       10000   11500.0        15
# 1446      04:05.0       10000   13000.0        30
# 1447      09:33.0       40000   48000.0        60
# 1448      46:49.0       60000   68100.0        90
# 1449      12:03.0       20000   22250.0        15
#
#                             referredby        age bank_account_type  \
# 0                                  NaN  32.618182               NaN
# 1                                  NaN  32.618182               NaN
# 2                                  NaN  36.000000           Savings
# 3                                  NaN  32.618182               NaN
# 4                                  NaN  42.000000           Savings
# ...                                ...        ...               ...
# 1445                               NaN  32.618182               NaN
# 1446                               NaN  32.618182               NaN
# 1447                               NaN  32.618182               NaN
# 1448                               NaN  32.618182               NaN
# 1449  8a858ff259d1429e0159d2d0194c4b8e  32.618182               NaN
#
#       longitude_gps  latitude_gps bank_name_clients bank_branch_clients  \
# 0               NaN           NaN               NaN                 NaN
# 1               NaN           NaN               NaN                 NaN
# 2          3.227945      6.586668               UBA                 NaN
# 3               NaN           NaN               NaN                 NaN
# 4          5.248368     13.059864               UBA                 NaN
# ...             ...           ...               ...                 ...
# 1445            NaN           NaN               NaN                 NaN
# 1446            NaN           NaN               NaN                 NaN
# 1447            NaN           NaN               NaN                 NaN
# 1448            NaN           NaN               NaN                 NaN
# 1449            NaN           NaN               NaN                 NaN
#
#      employment_status_clients level_of_education_clients
# 0                   Unemployed                        NaN
# 1                   Unemployed                        NaN
# 2                    Permanent                        NaN
# 3                   Unemployed                        NaN
# 4                    Permanent                        NaN
# ...                        ...                        ...
# 1445                Unemployed                        NaN
# 1446                Unemployed                        NaN
# 1447                Unemployed                        NaN
# 1448                Unemployed                        NaN
# 1449                Unemployed                        NaN
#
# [1450 rows x 17 columns]

# %% [markdown]
# ##### Niveau d'éducation des clients

# %%
train_data["level_of_education_clients"].value_counts()
# Out:
# Graduate         33
# Secondary         7
# Post-Graduate     6
# Primary           1
# Name: level_of_education_clients, dtype: int64

# %% [markdown]
# ##### remplacer les valeurs NaN par Undefined pour level_of_education_clients

# %%
train_data["level_of_education_clients"].fillna(value="Undefined", inplace=True)
train_data
# Out:
#                             customerid  systemloanid  loannumber approveddate  \
# 0     8a858899538ddb8e015390510b321f08     301998974           4      40:48.0
# 1     8a858959537a097401537a4e316e25f7     301963615          10      43:40.0
# 2     8a8589c253ace09b0153af6ba58f1f31     301982236           6      15:11.0
# 3     8a858e095aae82b7015aae86ca1e030b     301971730           8      00:54.0
# 4     8a858e225a28c713015a30db5c48383d     301959177           4      04:33.0
# ...                                ...           ...         ...          ...
# 1445  8a858fb45bb59c21015bb88a191f58f2     301991141           3      47:02.0
# 1446  8a858fcb5b00cc54015b0253ced26a5f     301963018           3      00:45.0
# 1447  8a858fde56eb02280156f59b976d46c0     301994653           9      09:40.0
# 1448  8a858e10570f2d65015717fcfec44996     301961483          14      47:54.0
# 1449  8a858f605b911d60015b91b99d55400d     301973097           6      12:09.0
#
#      creationdate  loanamount  totaldue  termdays  \
# 0         39:35.0       10000   12250.0        30
# 1         42:34.0       40000   44000.0        30
# 2         15:04.0       20000   24500.0        30
# 3         00:49.0       30000   34500.0        30
# 4         04:27.0       20000   24500.0        30
# ...           ...         ...       ...       ...
# 1445      46:53.0       10000   11500.0        15
# 1446      04:05.0       10000   13000.0        30
# 1447      09:33.0       40000   48000.0        60
# 1448      46:49.0       60000   68100.0        90
# 1449      12:03.0       20000   22250.0        15
#
#                             referredby        age bank_account_type  \
# 0                                  NaN  32.618182               NaN
# 1                                  NaN  32.618182               NaN
# 2                                  NaN  36.000000           Savings
# 3                                  NaN  32.618182               NaN
# 4                                  NaN  42.000000           Savings
# ...                                ...        ...               ...
# 1445                               NaN  32.618182               NaN
# 1446                               NaN  32.618182               NaN
# 1447                               NaN  32.618182               NaN
# 1448                               NaN  32.618182               NaN
# 1449  8a858ff259d1429e0159d2d0194c4b8e  32.618182               NaN
#
#       longitude_gps  latitude_gps bank_name_clients bank_branch_clients  \
# 0               NaN           NaN               NaN                 NaN
# 1               NaN           NaN               NaN                 NaN
# 2          3.227945      6.586668               UBA                 NaN
# 3               NaN           NaN               NaN                 NaN
# 4          5.248368     13.059864               UBA                 NaN
# ...             ...           ...               ...                 ...
# 1445            NaN           NaN               NaN                 NaN
# 1446            NaN           NaN               NaN                 NaN
# 1447            NaN           NaN               NaN                 NaN
# 1448            NaN           NaN               NaN                 NaN
# 1449            NaN           NaN               NaN                 NaN
#
#      employment_status_clients level_of_education_clients
# 0                   Unemployed                  Undefined
# 1                   Unemployed                  Undefined
# 2                    Permanent                  Undefined
# 3                   Unemployed                  Undefined
# 4                    Permanent                  Undefined
# ...                        ...                        ...
# 1445                Unemployed                  Undefined
# 1446                Unemployed                  Undefined
# 1447                Unemployed                  Undefined
# 1448                Unemployed                  Undefined
# 1449                Unemployed                  Undefined
#
# [1450 rows x 17 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1450 entries, 0 to 1449
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customerid                  1450 non-null   object
#  1   systemloanid                1450 non-null   int64
#  2   loannumber                  1450 non-null   int64
#  3   approveddate                1450 non-null   object
#  4   creationdate                1450 non-null   object
#  5   loanamount                  1450 non-null   int64
#  6   totaldue                    1450 non-null   float64
#  7   termdays                    1450 non-null   int64
#  8   referredby                  184 non-null    object
#  9   age                         1450 non-null   float64
#  10  bank_account_type           385 non-null    object
#  11  longitude_gps               385 non-null    float64
#  12  latitude_gps                385 non-null    float64
#  13  bank_name_clients           385 non-null    object
#  14  bank_branch_clients         4 non-null      object
#  15  employment_status_clients   1450 non-null   object
#  16  level_of_education_clients  1450 non-null   object
# dtypes: float64(4), int64(4), object(9)
# memory usage: 203.9+ KB

# %% [markdown]
# ##### Effacer les colonnes que l'on n'utilisera pas

# %%
train_data.drop(['referredby', 'longitude_gps', 'latitude_gps', 'bank_name_clients', 'bank_branch_clients'], axis=1, inplace=True)

# %%
train_data
# Out:
#                             customerid  systemloanid  loannumber approveddate  \
# 0     8a858899538ddb8e015390510b321f08     301998974           4      40:48.0
# 1     8a858959537a097401537a4e316e25f7     301963615          10      43:40.0
# 2     8a8589c253ace09b0153af6ba58f1f31     301982236           6      15:11.0
# 3     8a858e095aae82b7015aae86ca1e030b     301971730           8      00:54.0
# 4     8a858e225a28c713015a30db5c48383d     301959177           4      04:33.0
# ...                                ...           ...         ...          ...
# 1445  8a858fb45bb59c21015bb88a191f58f2     301991141           3      47:02.0
# 1446  8a858fcb5b00cc54015b0253ced26a5f     301963018           3      00:45.0
# 1447  8a858fde56eb02280156f59b976d46c0     301994653           9      09:40.0
# 1448  8a858e10570f2d65015717fcfec44996     301961483          14      47:54.0
# 1449  8a858f605b911d60015b91b99d55400d     301973097           6      12:09.0
#
#      creationdate  loanamount  totaldue  termdays        age  \
# 0         39:35.0       10000   12250.0        30  32.618182
# 1         42:34.0       40000   44000.0        30  32.618182
# 2         15:04.0       20000   24500.0        30  36.000000
# 3         00:49.0       30000   34500.0        30  32.618182
# 4         04:27.0       20000   24500.0        30  42.000000
# ...           ...         ...       ...       ...        ...
# 1445      46:53.0       10000   11500.0        15  32.618182
# 1446      04:05.0       10000   13000.0        30  32.618182
# 1447      09:33.0       40000   48000.0        60  32.618182
# 1448      46:49.0       60000   68100.0        90  32.618182
# 1449      12:03.0       20000   22250.0        15  32.618182
#
#      bank_account_type employment_status_clients level_of_education_clients
# 0                  NaN                Unemployed                  Undefined
# 1                  NaN                Unemployed                  Undefined
# 2              Savings                 Permanent                  Undefined
# 3                  NaN                Unemployed                  Undefined
# 4              Savings                 Permanent                  Undefined
# ...                ...                       ...                        ...
# 1445               NaN                Unemployed                  Undefined
# 1446               NaN                Unemployed                  Undefined
# 1447               NaN                Unemployed                  Undefined
# 1448               NaN                Unemployed                  Undefined
# 1449               NaN                Unemployed                  Undefined
#
# [1450 rows x 12 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1450 entries, 0 to 1449
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customerid                  1450 non-null   object
#  1   systemloanid                1450 non-null   int64
#  2   loannumber                  1450 non-null   int64
#  3   approveddate                1450 non-null   object
#  4   creationdate                1450 non-null   object
#  5   loanamount                  1450 non-null   int64
#  6   totaldue                    1450 non-null   float64
#  7   termdays                    1450 non-null   int64
#  8   age                         1450 non-null   float64
#  9   bank_account_type           385 non-null    object
#  10  employment_status_clients   1450 non-null   object
#  11  level_of_education_clients  1450 non-null   object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 147.3+ KB

# %% [markdown]
# ##### remplacer les valeurs du target good_bad_flag par 0 ou 1

# %%
#labelencoder = LabelEncoder()
#train_data['good_bad_flag'] = labelencoder.fit_transform(train_data['good_bad_flag'])
#train_data

# %% [markdown]
# ##### visualiser la target variable

# %%
#plt.figure(figsize=(10,6))
#palette_color = sns.color_palette('bright')
#plt.pie(train_data['good_bad_flag'].value_counts(),colors= palette_color, autopct='%.0f%%') 
#plt.legend(["1: paid loan","0: not paid loan"])

# %% [markdown]
# ## Visualisation des features

# %% [markdown]
# #### employement_status_clients

# %% [markdown]
# #### level_of_education

# %% [markdown]
# ##### age

# %% [markdown]
# ### termdays

# %% [markdown]
# ### Add loan interest features

# %%
def loan_interest(loanamount,totaldue):
    loan_interest = ((totaldue - loanamount)/loanamount) * 100
    return loan_interest

# %%
train_data['loan_interest'] = train_data.apply(lambda x: loan_interest(x["loanamount"], x["totaldue"]),axis=1)
train_data
# Out:
#                             customerid  systemloanid  loannumber approveddate  \
# 0     8a858899538ddb8e015390510b321f08     301998974           4      40:48.0
# 1     8a858959537a097401537a4e316e25f7     301963615          10      43:40.0
# 2     8a8589c253ace09b0153af6ba58f1f31     301982236           6      15:11.0
# 3     8a858e095aae82b7015aae86ca1e030b     301971730           8      00:54.0
# 4     8a858e225a28c713015a30db5c48383d     301959177           4      04:33.0
# ...                                ...           ...         ...          ...
# 1445  8a858fb45bb59c21015bb88a191f58f2     301991141           3      47:02.0
# 1446  8a858fcb5b00cc54015b0253ced26a5f     301963018           3      00:45.0
# 1447  8a858fde56eb02280156f59b976d46c0     301994653           9      09:40.0
# 1448  8a858e10570f2d65015717fcfec44996     301961483          14      47:54.0
# 1449  8a858f605b911d60015b91b99d55400d     301973097           6      12:09.0
#
#      creationdate  loanamount  totaldue  termdays        age  \
# 0         39:35.0       10000   12250.0        30  32.618182
# 1         42:34.0       40000   44000.0        30  32.618182
# 2         15:04.0       20000   24500.0        30  36.000000
# 3         00:49.0       30000   34500.0        30  32.618182
# 4         04:27.0       20000   24500.0        30  42.000000
# ...           ...         ...       ...       ...        ...
# 1445      46:53.0       10000   11500.0        15  32.618182
# 1446      04:05.0       10000   13000.0        30  32.618182
# 1447      09:33.0       40000   48000.0        60  32.618182
# 1448      46:49.0       60000   68100.0        90  32.618182
# 1449      12:03.0       20000   22250.0        15  32.618182
#
#      bank_account_type employment_status_clients level_of_education_clients  \
# 0                  NaN                Unemployed                  Undefined
# 1                  NaN                Unemployed                  Undefined
# 2              Savings                 Permanent                  Undefined
# 3                  NaN                Unemployed                  Undefined
# 4              Savings                 Permanent                  Undefined
# ...                ...                       ...                        ...
# 1445               NaN                Unemployed                  Undefined
# 1446               NaN                Unemployed                  Undefined
# 1447               NaN                Unemployed                  Undefined
# 1448               NaN                Unemployed                  Undefined
# 1449               NaN                Unemployed                  Undefined
#
#       loan_interest
# 0             22.50
# 1             10.00
# 2             22.50
# 3             15.00
# 4             22.50
# ...             ...
# 1445          15.00
# 1446          30.00
# 1447          20.00
# 1448          13.50
# 1449          11.25
#
# [1450 rows x 13 columns]

# %% [markdown]
# ## utiliser train_prevloans
# grouper les informations de train_prevloans de chaque clients pour determiner loan_received, amount_received, min_amount_received, max_amount_received

# %%
train_data_prev_loans = train_prevloans.groupby('customerid')['loanamount'].agg(['count','sum','min', 'max'])
train_data_prev_loans
# Out:
#                                   count       sum      min      max
# customerid
# 8a28afc7474813a40147639ec637156b     10  178000.0   8000.0  30000.0
# 8a3735d5518aba7301518ac34413010d      6   70000.0  10000.0  20000.0
# 8a76e7d443e6e97c0143ed099d102b1d      2   20000.0  10000.0  10000.0
# 8a818823525dceef01525deda2480384      9  170000.0   5000.0  40000.0
# 8a818926522ea5ef01523aff15c37482      2   20000.0  10000.0  10000.0
# ...                                 ...       ...      ...      ...
# 8a858fff5a36fe68015a3744f0021e89      5   65000.0  10000.0  20000.0
# 8aaae7a74400b28201441c8b62514150      3   30000.0  10000.0  10000.0
# 8aab10f748cf78ff0148d11fac1447a6      1   10000.0  10000.0  10000.0
# 8aab160f499477da014999ba2f0f578b      3   30000.0  10000.0  10000.0
# 8addcb0645aff34b0145b25fe1616ee0      4   40000.0  10000.0  10000.0
#
# [1442 rows x 4 columns]

# %%
train_data_prev_loans.rename(columns = {'count':'loan_received'}, inplace=True)
train_data_prev_loans.rename(columns = {'sum':'amount_received'}, inplace=True)
train_data_prev_loans.rename(columns = {'min':'min_amount_received'}, inplace=True)
train_data_prev_loans.rename(columns = {'max':'max_amount_received'}, inplace=True)
train_data_prev_loans
# Out:
#                                   loan_received  amount_received  \
# customerid
# 8a28afc7474813a40147639ec637156b             10         178000.0
# 8a3735d5518aba7301518ac34413010d              6          70000.0
# 8a76e7d443e6e97c0143ed099d102b1d              2          20000.0
# 8a818823525dceef01525deda2480384              9         170000.0
# 8a818926522ea5ef01523aff15c37482              2          20000.0
# ...                                         ...              ...
# 8a858fff5a36fe68015a3744f0021e89              5          65000.0
# 8aaae7a74400b28201441c8b62514150              3          30000.0
# 8aab10f748cf78ff0148d11fac1447a6              1          10000.0
# 8aab160f499477da014999ba2f0f578b              3          30000.0
# 8addcb0645aff34b0145b25fe1616ee0              4          40000.0
#
#                                   min_amount_received  max_amount_received
# customerid
# 8a28afc7474813a40147639ec637156b               8000.0              30000.0
# 8a3735d5518aba7301518ac34413010d              10000.0              20000.0
# 8a76e7d443e6e97c0143ed099d102b1d              10000.0              10000.0
# 8a818823525dceef01525deda2480384               5000.0              40000.0
# 8a818926522ea5ef01523aff15c37482              10000.0              10000.0
# ...                                               ...                  ...
# 8a858fff5a36fe68015a3744f0021e89              10000.0              20000.0
# 8aaae7a74400b28201441c8b62514150              10000.0              10000.0
# 8aab10f748cf78ff0148d11fac1447a6              10000.0              10000.0
# 8aab160f499477da014999ba2f0f578b              10000.0              10000.0
# 8addcb0645aff34b0145b25fe1616ee0              10000.0              10000.0
#
# [1442 rows x 4 columns]

# %%
train_data_prev_loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1442 entries, 8a28afc7474813a40147639ec637156b to 8addcb0645aff34b0145b25fe1616ee0
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   loan_received        1442 non-null   int64
#  1   amount_received      1442 non-null   float64
#  2   min_amount_received  1442 non-null   float64
#  3   max_amount_received  1442 non-null   float64
# dtypes: float64(3), int64(1)
# memory usage: 56.3+ KB

# %% [markdown]
# ### merger train_data_prev_loans dans train_data

# %%
train_data = train_data.merge(right=train_data_prev_loans , on='customerid', how='left')
train_data
# Out:
#                             customerid  systemloanid  loannumber approveddate  \
# 0     8a858899538ddb8e015390510b321f08     301998974           4      40:48.0
# 1     8a858959537a097401537a4e316e25f7     301963615          10      43:40.0
# 2     8a8589c253ace09b0153af6ba58f1f31     301982236           6      15:11.0
# 3     8a858e095aae82b7015aae86ca1e030b     301971730           8      00:54.0
# 4     8a858e225a28c713015a30db5c48383d     301959177           4      04:33.0
# ...                                ...           ...         ...          ...
# 1445  8a858fb45bb59c21015bb88a191f58f2     301991141           3      47:02.0
# 1446  8a858fcb5b00cc54015b0253ced26a5f     301963018           3      00:45.0
# 1447  8a858fde56eb02280156f59b976d46c0     301994653           9      09:40.0
# 1448  8a858e10570f2d65015717fcfec44996     301961483          14      47:54.0
# 1449  8a858f605b911d60015b91b99d55400d     301973097           6      12:09.0
#
#      creationdate  loanamount  totaldue  termdays        age  \
# 0         39:35.0       10000   12250.0        30  32.618182
# 1         42:34.0       40000   44000.0        30  32.618182
# 2         15:04.0       20000   24500.0        30  36.000000
# 3         00:49.0       30000   34500.0        30  32.618182
# 4         04:27.0       20000   24500.0        30  42.000000
# ...           ...         ...       ...       ...        ...
# 1445      46:53.0       10000   11500.0        15  32.618182
# 1446      04:05.0       10000   13000.0        30  32.618182
# 1447      09:33.0       40000   48000.0        60  32.618182
# 1448      46:49.0       60000   68100.0        90  32.618182
# 1449      12:03.0       20000   22250.0        15  32.618182
#
#      bank_account_type employment_status_clients level_of_education_clients  \
# 0                  NaN                Unemployed                  Undefined
# 1                  NaN                Unemployed                  Undefined
# 2              Savings                 Permanent                  Undefined
# 3                  NaN                Unemployed                  Undefined
# 4              Savings                 Permanent                  Undefined
# ...                ...                       ...                        ...
# 1445               NaN                Unemployed                  Undefined
# 1446               NaN                Unemployed                  Undefined
# 1447               NaN                Unemployed                  Undefined
# 1448               NaN                Unemployed                  Undefined
# 1449               NaN                Unemployed                  Undefined
#
#       loan_interest  loan_received  amount_received  min_amount_received  \
# 0             22.50            3.0          26000.0               6000.0
# 1             10.00            9.0         215000.0               5000.0
# 2             22.50            5.0          65000.0              10000.0
# 3             15.00            7.0         120000.0              10000.0
# 4             22.50            3.0          30000.0              10000.0
# ...             ...            ...              ...                  ...
# 1445          15.00            2.0          20000.0              10000.0
# 1446          30.00            2.0          20000.0              10000.0
# 1447          20.00            8.0         145000.0              10000.0
# 1448          13.50           13.0         395000.0              10000.0
# 1449          11.25            5.0          50000.0              10000.0
#
#       max_amount_received
# 0                 10000.0
# 1                 40000.0
# 2                 20000.0
# 3                 30000.0
# 4                 10000.0
# ...                   ...
# 1445              10000.0
# 1446              10000.0
# 1447              30000.0
# 1448              50000.0
# 1449              10000.0
#
# [1450 rows x 17 columns]

# %% [markdown]
# remplacer les valeurs null par 0

# %%
train_data['loan_received'].fillna(0, inplace =True)
train_data['amount_received'].fillna(0, inplace =True)
train_data['min_amount_received'].fillna(0, inplace =True)
train_data['max_amount_received'].fillna(0, inplace =True) 
train_data
# Out:
#                             customerid  systemloanid  loannumber approveddate  \
# 0     8a858899538ddb8e015390510b321f08     301998974           4      40:48.0
# 1     8a858959537a097401537a4e316e25f7     301963615          10      43:40.0
# 2     8a8589c253ace09b0153af6ba58f1f31     301982236           6      15:11.0
# 3     8a858e095aae82b7015aae86ca1e030b     301971730           8      00:54.0
# 4     8a858e225a28c713015a30db5c48383d     301959177           4      04:33.0
# ...                                ...           ...         ...          ...
# 1445  8a858fb45bb59c21015bb88a191f58f2     301991141           3      47:02.0
# 1446  8a858fcb5b00cc54015b0253ced26a5f     301963018           3      00:45.0
# 1447  8a858fde56eb02280156f59b976d46c0     301994653           9      09:40.0
# 1448  8a858e10570f2d65015717fcfec44996     301961483          14      47:54.0
# 1449  8a858f605b911d60015b91b99d55400d     301973097           6      12:09.0
#
#      creationdate  loanamount  totaldue  termdays        age  \
# 0         39:35.0       10000   12250.0        30  32.618182
# 1         42:34.0       40000   44000.0        30  32.618182
# 2         15:04.0       20000   24500.0        30  36.000000
# 3         00:49.0       30000   34500.0        30  32.618182
# 4         04:27.0       20000   24500.0        30  42.000000
# ...           ...         ...       ...       ...        ...
# 1445      46:53.0       10000   11500.0        15  32.618182
# 1446      04:05.0       10000   13000.0        30  32.618182
# 1447      09:33.0       40000   48000.0        60  32.618182
# 1448      46:49.0       60000   68100.0        90  32.618182
# 1449      12:03.0       20000   22250.0        15  32.618182
#
#      bank_account_type employment_status_clients level_of_education_clients  \
# 0                  NaN                Unemployed                  Undefined
# 1                  NaN                Unemployed                  Undefined
# 2              Savings                 Permanent                  Undefined
# 3                  NaN                Unemployed                  Undefined
# 4              Savings                 Permanent                  Undefined
# ...                ...                       ...                        ...
# 1445               NaN                Unemployed                  Undefined
# 1446               NaN                Unemployed                  Undefined
# 1447               NaN                Unemployed                  Undefined
# 1448               NaN                Unemployed                  Undefined
# 1449               NaN                Unemployed                  Undefined
#
#       loan_interest  loan_received  amount_received  min_amount_received  \
# 0             22.50            3.0          26000.0               6000.0
# 1             10.00            9.0         215000.0               5000.0
# 2             22.50            5.0          65000.0              10000.0
# 3             15.00            7.0         120000.0              10000.0
# 4             22.50            3.0          30000.0              10000.0
# ...             ...            ...              ...                  ...
# 1445          15.00            2.0          20000.0              10000.0
# 1446          30.00            2.0          20000.0              10000.0
# 1447          20.00            8.0         145000.0              10000.0
# 1448          13.50           13.0         395000.0              10000.0
# 1449          11.25            5.0          50000.0              10000.0
#
#       max_amount_received
# 0                 10000.0
# 1                 40000.0
# 2                 20000.0
# 3                 30000.0
# 4                 10000.0
# ...                   ...
# 1445              10000.0
# 1446              10000.0
# 1447              30000.0
# 1448              50000.0
# 1449              10000.0
#
# [1450 rows x 17 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1450 entries, 0 to 1449
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customerid                  1450 non-null   object
#  1   systemloanid                1450 non-null   int64
#  2   loannumber                  1450 non-null   int64
#  3   approveddate                1450 non-null   object
#  4   creationdate                1450 non-null   object
#  5   loanamount                  1450 non-null   int64
#  6   totaldue                    1450 non-null   float64
#  7   termdays                    1450 non-null   int64
#  8   age                         1450 non-null   float64
#  9   bank_account_type           385 non-null    object
#  10  employment_status_clients   1450 non-null   object
#  11  level_of_education_clients  1450 non-null   object
#  12  loan_interest               1450 non-null   float64
#  13  loan_received               1450 non-null   float64
#  14  amount_received             1450 non-null   float64
#  15  min_amount_received         1450 non-null   float64
#  16  max_amount_received         1450 non-null   float64
# dtypes: float64(7), int64(4), object(6)
# memory usage: 203.9+ KB

# %%
del train_data["bank_account_type"]
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1450 entries, 0 to 1449
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customerid                  1450 non-null   object
#  1   systemloanid                1450 non-null   int64
#  2   loannumber                  1450 non-null   int64
#  3   approveddate                1450 non-null   object
#  4   creationdate                1450 non-null   object
#  5   loanamount                  1450 non-null   int64
#  6   totaldue                    1450 non-null   float64
#  7   termdays                    1450 non-null   int64
#  8   age                         1450 non-null   float64
#  9   employment_status_clients   1450 non-null   object
#  10  level_of_education_clients  1450 non-null   object
#  11  loan_interest               1450 non-null   float64
#  12  loan_received               1450 non-null   float64
#  13  amount_received             1450 non-null   float64
#  14  min_amount_received         1450 non-null   float64
#  15  max_amount_received         1450 non-null   float64
# dtypes: float64(7), int64(4), object(5)
# memory usage: 192.6+ KB

# %% [markdown]
# # Exploration des données

# %%
train_data.hist(figsize=(20, 20))
# Out:
# array([[<AxesSubplot:title={'center':'systemloanid'}>,
#         <AxesSubplot:title={'center':'loannumber'}>,
#         <AxesSubplot:title={'center':'loanamount'}>],
#        [<AxesSubplot:title={'center':'totaldue'}>,
#         <AxesSubplot:title={'center':'termdays'}>,
#         <AxesSubplot:title={'center':'age'}>],
#        [<AxesSubplot:title={'center':'loan_interest'}>,
#         <AxesSubplot:title={'center':'loan_received'}>,
#         <AxesSubplot:title={'center':'amount_received'}>],
#        [<AxesSubplot:title={'center':'min_amount_received'}>,
#         <AxesSubplot:title={'center':'max_amount_received'}>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ### Correlation

# %%
plt.figure(figsize=(10,6))
sns.heatmap(train_data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### visualisation

# %%
data_temp = pd.get_dummies(train_data[['employment_status_clients', 'level_of_education_clients']])
data_temp
# Out:
#       employment_status_clients_Permanent  employment_status_clients_Retired  \
# 0                                       0                                  0
# 1                                       0                                  0
# 2                                       1                                  0
# 3                                       0                                  0
# 4                                       1                                  0
# ...                                   ...                                ...
# 1445                                    0                                  0
# 1446                                    0                                  0
# 1447                                    0                                  0
# 1448                                    0                                  0
# 1449                                    0                                  0
#
#       employment_status_clients_Self-Employed  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
# ...                                       ...
# 1445                                        0
# 1446                                        0
# 1447                                        0
# 1448                                        0
# 1449                                        0
#
#       employment_status_clients_Student  employment_status_clients_Unemployed  \
# 0                                     0                                     1
# 1                                     0                                     1
# 2                                     0                                     0
# 3                                     0                                     1
# 4                                     0                                     0
# ...                                 ...                                   ...
# 1445                                  0                                     1
# 1446                                  0                                     1
# 1447                                  0                                     1
# 1448                                  0                                     1
# 1449                                  0                                     1
#
#       level_of_education_clients_Graduate  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 1445                                    0
# 1446                                    0
# 1447                                    0
# 1448                                    0
# 1449                                    0
#
#       level_of_education_clients_Post-Graduate  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
# ...                                        ...
# 1445                                         0
# 1446                                         0
# 1447                                         0
# 1448                                         0
# 1449                                         0
#
#       level_of_education_clients_Primary  \
# 0                                      0
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      0
# ...                                  ...
# 1445                                   0
# 1446                                   0
# 1447                                   0
# 1448                                   0
# 1449                                   0
#
#       level_of_education_clients_Secondary  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...                                    ...
# 1445                                     0
# 1446                                     0
# 1447                                     0
# 1448                                     0
# 1449                                     0
#
#       level_of_education_clients_Undefined
# 0                                        1
# 1                                        1
# 2                                        1
# 3                                        1
# 4                                        1
# ...                                    ...
# 1445                                     1
# 1446                                     1
# 1447                                     1
# 1448                                     1
# 1449                                     1
#
# [1450 rows x 10 columns]

# %%
train_data = train_data.join(data_temp)
train_data
# Out:
#                             customerid  systemloanid  loannumber approveddate  \
# 0     8a858899538ddb8e015390510b321f08     301998974           4      40:48.0
# 1     8a858959537a097401537a4e316e25f7     301963615          10      43:40.0
# 2     8a8589c253ace09b0153af6ba58f1f31     301982236           6      15:11.0
# 3     8a858e095aae82b7015aae86ca1e030b     301971730           8      00:54.0
# 4     8a858e225a28c713015a30db5c48383d     301959177           4      04:33.0
# ...                                ...           ...         ...          ...
# 1445  8a858fb45bb59c21015bb88a191f58f2     301991141           3      47:02.0
# 1446  8a858fcb5b00cc54015b0253ced26a5f     301963018           3      00:45.0
# 1447  8a858fde56eb02280156f59b976d46c0     301994653           9      09:40.0
# 1448  8a858e10570f2d65015717fcfec44996     301961483          14      47:54.0
# 1449  8a858f605b911d60015b91b99d55400d     301973097           6      12:09.0
#
#      creationdate  loanamount  totaldue  termdays        age  \
# 0         39:35.0       10000   12250.0        30  32.618182
# 1         42:34.0       40000   44000.0        30  32.618182
# 2         15:04.0       20000   24500.0        30  36.000000
# 3         00:49.0       30000   34500.0        30  32.618182
# 4         04:27.0       20000   24500.0        30  42.000000
# ...           ...         ...       ...       ...        ...
# 1445      46:53.0       10000   11500.0        15  32.618182
# 1446      04:05.0       10000   13000.0        30  32.618182
# 1447      09:33.0       40000   48000.0        60  32.618182
# 1448      46:49.0       60000   68100.0        90  32.618182
# 1449      12:03.0       20000   22250.0        15  32.618182
#
#      employment_status_clients  ... employment_status_clients_Permanent  \
# 0                   Unemployed  ...                                   0
# 1                   Unemployed  ...                                   0
# 2                    Permanent  ...                                   1
# 3                   Unemployed  ...                                   0
# 4                    Permanent  ...                                   1
# ...                        ...  ...                                 ...
# 1445                Unemployed  ...                                   0
# 1446                Unemployed  ...                                   0
# 1447                Unemployed  ...                                   0
# 1448                Unemployed  ...                                   0
# 1449                Unemployed  ...                                   0
#
#       employment_status_clients_Retired  \
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     0
# 4                                     0
# ...                                 ...
# 1445                                  0
# 1446                                  0
# 1447                                  0
# 1448                                  0
# 1449                                  0
#
#       employment_status_clients_Self-Employed  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
# ...                                       ...
# 1445                                        0
# 1446                                        0
# 1447                                        0
# 1448                                        0
# 1449                                        0
#
#       employment_status_clients_Student  employment_status_clients_Unemployed  \
# 0                                     0                                     1
# 1                                     0                                     1
# 2                                     0                                     0
# 3                                     0                                     1
# 4                                     0                                     0
# ...                                 ...                                   ...
# 1445                                  0                                     1
# 1446                                  0                                     1
# 1447                                  0                                     1
# 1448                                  0                                     1
# 1449                                  0                                     1
#
#       level_of_education_clients_Graduate  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 1445                                    0
# 1446                                    0
# 1447                                    0
# 1448                                    0
# 1449                                    0
#
#       level_of_education_clients_Post-Graduate  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
# ...                                        ...
# 1445                                         0
# 1446                                         0
# 1447                                         0
# 1448                                         0
# 1449                                         0
#
#       level_of_education_clients_Primary  \
# 0                                      0
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      0
# ...                                  ...
# 1445                                   0
# 1446                                   0
# 1447                                   0
# 1448                                   0
# 1449                                   0
#
#       level_of_education_clients_Secondary  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...                                    ...
# 1445                                     0
# 1446                                     0
# 1447                                     0
# 1448                                     0
# 1449                                     0
#
#       level_of_education_clients_Undefined
# 0                                        1
# 1                                        1
# 2                                        1
# 3                                        1
# 4                                        1
# ...                                    ...
# 1445                                     1
# 1446                                     1
# 1447                                     1
# 1448                                     1
# 1449                                     1
#
# [1450 rows x 26 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1450 entries, 0 to 1449
# Data columns (total 26 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   customerid                                1450 non-null   object
#  1   systemloanid                              1450 non-null   int64
#  2   loannumber                                1450 non-null   int64
#  3   approveddate                              1450 non-null   object
#  4   creationdate                              1450 non-null   object
#  5   loanamount                                1450 non-null   int64
#  6   totaldue                                  1450 non-null   float64
#  7   termdays                                  1450 non-null   int64
#  8   age                                       1450 non-null   float64
#  9   employment_status_clients                 1450 non-null   object
#  10  level_of_education_clients                1450 non-null   object
#  11  loan_interest                             1450 non-null   float64
#  12  loan_received                             1450 non-null   float64
#  13  amount_received                           1450 non-null   float64
#  14  min_amount_received                       1450 non-null   float64
#  15  max_amount_received                       1450 non-null   float64
#  16  employment_status_clients_Permanent       1450 non-null   uint8
#  17  employment_status_clients_Retired         1450 non-null   uint8
#  18  employment_status_clients_Self-Employed   1450 non-null   uint8
#  19  employment_status_clients_Student         1450 non-null   uint8
#  20  employment_status_clients_Unemployed      1450 non-null   uint8
#  21  level_of_education_clients_Graduate       1450 non-null   uint8
#  22  level_of_education_clients_Post-Graduate  1450 non-null   uint8
#  23  level_of_education_clients_Primary        1450 non-null   uint8
#  24  level_of_education_clients_Secondary      1450 non-null   uint8
#  25  level_of_education_clients_Undefined      1450 non-null   uint8
# dtypes: float64(7), int64(4), object(5), uint8(10)
# memory usage: 239.0+ KB

# %%
customerid = train_data["customerid"]
customerid
# Out:
# 0       8a858899538ddb8e015390510b321f08
# 1       8a858959537a097401537a4e316e25f7
# 2       8a8589c253ace09b0153af6ba58f1f31
# 3       8a858e095aae82b7015aae86ca1e030b
# 4       8a858e225a28c713015a30db5c48383d
#                       ...
# 1445    8a858fb45bb59c21015bb88a191f58f2
# 1446    8a858fcb5b00cc54015b0253ced26a5f
# 1447    8a858fde56eb02280156f59b976d46c0
# 1448    8a858e10570f2d65015717fcfec44996
# 1449    8a858f605b911d60015b91b99d55400d
# Name: customerid, Length: 1450, dtype: object

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1450 entries, 0 to 1449
# Data columns (total 26 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   customerid                                1450 non-null   object
#  1   systemloanid                              1450 non-null   int64
#  2   loannumber                                1450 non-null   int64
#  3   approveddate                              1450 non-null   object
#  4   creationdate                              1450 non-null   object
#  5   loanamount                                1450 non-null   int64
#  6   totaldue                                  1450 non-null   float64
#  7   termdays                                  1450 non-null   int64
#  8   age                                       1450 non-null   float64
#  9   employment_status_clients                 1450 non-null   object
#  10  level_of_education_clients                1450 non-null   object
#  11  loan_interest                             1450 non-null   float64
#  12  loan_received                             1450 non-null   float64
#  13  amount_received                           1450 non-null   float64
#  14  min_amount_received                       1450 non-null   float64
#  15  max_amount_received                       1450 non-null   float64
#  16  employment_status_clients_Permanent       1450 non-null   uint8
#  17  employment_status_clients_Retired         1450 non-null   uint8
#  18  employment_status_clients_Self-Employed   1450 non-null   uint8
#  19  employment_status_clients_Student         1450 non-null   uint8
#  20  employment_status_clients_Unemployed      1450 non-null   uint8
#  21  level_of_education_clients_Graduate       1450 non-null   uint8
#  22  level_of_education_clients_Post-Graduate  1450 non-null   uint8
#  23  level_of_education_clients_Primary        1450 non-null   uint8
#  24  level_of_education_clients_Secondary      1450 non-null   uint8
#  25  level_of_education_clients_Undefined      1450 non-null   uint8
# dtypes: float64(7), int64(4), object(5), uint8(10)
# memory usage: 239.0+ KB

# %%
train_data.drop(['systemloanid', 'approveddate', 'creationdate', 'employment_status_clients', 'level_of_education_clients'], axis=1, inplace=True)
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1450 entries, 0 to 1449
# Data columns (total 21 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   customerid                                1450 non-null   object
#  1   loannumber                                1450 non-null   int64
#  2   loanamount                                1450 non-null   int64
#  3   totaldue                                  1450 non-null   float64
#  4   termdays                                  1450 non-null   int64
#  5   age                                       1450 non-null   float64
#  6   loan_interest                             1450 non-null   float64
#  7   loan_received                             1450 non-null   float64
#  8   amount_received                           1450 non-null   float64
#  9   min_amount_received                       1450 non-null   float64
#  10  max_amount_received                       1450 non-null   float64
#  11  employment_status_clients_Permanent       1450 non-null   uint8
#  12  employment_status_clients_Retired         1450 non-null   uint8
#  13  employment_status_clients_Self-Employed   1450 non-null   uint8
#  14  employment_status_clients_Student         1450 non-null   uint8
#  15  employment_status_clients_Unemployed      1450 non-null   uint8
#  16  level_of_education_clients_Graduate       1450 non-null   uint8
#  17  level_of_education_clients_Post-Graduate  1450 non-null   uint8
#  18  level_of_education_clients_Primary        1450 non-null   uint8
#  19  level_of_education_clients_Secondary      1450 non-null   uint8
#  20  level_of_education_clients_Undefined      1450 non-null   uint8
# dtypes: float64(7), int64(3), object(1), uint8(10)
# memory usage: 182.4+ KB

# %%
train_data
# Out:
#                             customerid  loannumber  loanamount  totaldue  \
# 0     8a858899538ddb8e015390510b321f08           4       10000   12250.0
# 1     8a858959537a097401537a4e316e25f7          10       40000   44000.0
# 2     8a8589c253ace09b0153af6ba58f1f31           6       20000   24500.0
# 3     8a858e095aae82b7015aae86ca1e030b           8       30000   34500.0
# 4     8a858e225a28c713015a30db5c48383d           4       20000   24500.0
# ...                                ...         ...         ...       ...
# 1445  8a858fb45bb59c21015bb88a191f58f2           3       10000   11500.0
# 1446  8a858fcb5b00cc54015b0253ced26a5f           3       10000   13000.0
# 1447  8a858fde56eb02280156f59b976d46c0           9       40000   48000.0
# 1448  8a858e10570f2d65015717fcfec44996          14       60000   68100.0
# 1449  8a858f605b911d60015b91b99d55400d           6       20000   22250.0
#
#       termdays        age  loan_interest  loan_received  amount_received  \
# 0           30  32.618182          22.50            3.0          26000.0
# 1           30  32.618182          10.00            9.0         215000.0
# 2           30  36.000000          22.50            5.0          65000.0
# 3           30  32.618182          15.00            7.0         120000.0
# 4           30  42.000000          22.50            3.0          30000.0
# ...        ...        ...            ...            ...              ...
# 1445        15  32.618182          15.00            2.0          20000.0
# 1446        30  32.618182          30.00            2.0          20000.0
# 1447        60  32.618182          20.00            8.0         145000.0
# 1448        90  32.618182          13.50           13.0         395000.0
# 1449        15  32.618182          11.25            5.0          50000.0
#
#       min_amount_received  ...  employment_status_clients_Permanent  \
# 0                  6000.0  ...                                    0
# 1                  5000.0  ...                                    0
# 2                 10000.0  ...                                    1
# 3                 10000.0  ...                                    0
# 4                 10000.0  ...                                    1
# ...                   ...  ...                                  ...
# 1445              10000.0  ...                                    0
# 1446              10000.0  ...                                    0
# 1447              10000.0  ...                                    0
# 1448              10000.0  ...                                    0
# 1449              10000.0  ...                                    0
#
#       employment_status_clients_Retired  \
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     0
# 4                                     0
# ...                                 ...
# 1445                                  0
# 1446                                  0
# 1447                                  0
# 1448                                  0
# 1449                                  0
#
#       employment_status_clients_Self-Employed  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
# ...                                       ...
# 1445                                        0
# 1446                                        0
# 1447                                        0
# 1448                                        0
# 1449                                        0
#
#       employment_status_clients_Student  employment_status_clients_Unemployed  \
# 0                                     0                                     1
# 1                                     0                                     1
# 2                                     0                                     0
# 3                                     0                                     1
# 4                                     0                                     0
# ...                                 ...                                   ...
# 1445                                  0                                     1
# 1446                                  0                                     1
# 1447                                  0                                     1
# 1448                                  0                                     1
# 1449                                  0                                     1
#
#       level_of_education_clients_Graduate  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 1445                                    0
# 1446                                    0
# 1447                                    0
# 1448                                    0
# 1449                                    0
#
#       level_of_education_clients_Post-Graduate  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
# ...                                        ...
# 1445                                         0
# 1446                                         0
# 1447                                         0
# 1448                                         0
# 1449                                         0
#
#       level_of_education_clients_Primary  \
# 0                                      0
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      0
# ...                                  ...
# 1445                                   0
# 1446                                   0
# 1447                                   0
# 1448                                   0
# 1449                                   0
#
#       level_of_education_clients_Secondary  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...                                    ...
# 1445                                     0
# 1446                                     0
# 1447                                     0
# 1448                                     0
# 1449                                     0
#
#       level_of_education_clients_Undefined
# 0                                        1
# 1                                        1
# 2                                        1
# 3                                        1
# 4                                        1
# ...                                    ...
# 1445                                     1
# 1446                                     1
# 1447                                     1
# 1448                                     1
# 1449                                     1
#
# [1450 rows x 21 columns]

# %%
train_data.to_csv("testdata.csv")
